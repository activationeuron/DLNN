# %% [markdown]
# 1. Threshhold function,2.sigmoidfunction,3. hyperbolicTangent  (Tanh)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("./nuralnetwork.png")

# %%
def imgReadShow(path):
    import cv2
import matplotlib.pyplot as plt
    img=cv2.imread(path)
    plt.figure(figsize=(15,15))
    plt.imshow(img)

# %%
imgReadShow("./nuralnetwork.png")

# %% [markdown]
# #### w1,w2,w3 is a weight and X1,X2,X3 are inputs, the input values are feed into nural network, NN predict the output

# %% [markdown]
# #### the result is Y^(y hat) , The y^ is compared with the actual values i.e Y.

# %% [markdown]
# #### the cost function is use to determing the erroe , and the gole is to minimize cost  function

# %% [markdown]
# #### cost function is 1/2(y^-y)^2

# %%
imgReadShow("./backNN.png")

# %% [markdown]
# ### now in order to minimize the cost fucntion we have to update the weights , the cost/erroe is backproprageted into the NN to update the weights

# %%
imgReadShow("./nwithdata.png")

# %%
#every row have same weights
